# %%
import pandas as pd

# %%
df_1 = pd.read_csv('/Users/angelo/Desktop/PhD/defcon27_ai_village/datasets/static_images.csv')
df_1.head()
# Out:
#                                hash pix_0 pix_1 pix_2 pix_3 pix_4 pix_5 pix_6  \
# 0  b324140e1fb35dc6b694879ba1f2be45    15    15   239    15   223    36   102
# 1  1d32b1326a524b163eb74af645cd34d5   234   196     8    20   182    56    27
# 2  e44fea4913fc9fd91b8b07c4670aeac4   196   255     5    97    35   112   219
# 3  95badb16d862ba94ae85c44e4b31d749   232   252   183    39    51     1   255
# 4  f30f32a4f42678ef49a543356d580232    81    84   204   228   255   157    76
#
#   pix_7 pix_8  ... pix_1015 pix_1016 pix_1017 pix_1018 pix_1019 pix_1020  \
# 0   243   102  ...       31      242      245      169      212       17
# 1   223   144  ...      189      228      156       54      189       82
# 2   189   217  ...      254      189      227      255      192      231
# 3    87    94  ...      210       52       55       95      230       48
# 4   254   128  ...       24       69       64       53       52      216
#
#   pix_1021 pix_1022 pix_1023 malware
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51960 entries, 0 to 51959
# Columns: 1026 entries, hash to malware
# dtypes: object(1026)
# memory usage: 406.7+ MB
